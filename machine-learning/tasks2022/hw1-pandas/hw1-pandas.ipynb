# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import wget 
wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')
# Out:
# 'end_seminar (1).xlsx'

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> крайне нежелательно.

# %% [markdown]
# #### 1. [0 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
df = pd.read_excel("end_seminar.xlsx")
df.head()
# Out:
#                    timestamp                                id  rating  \
# 0 2020-05-15 01:12:50.543000  93ff79a51cd602f1dd3028ba2c129503     698
# 1 2020-05-15 02:46:48.066001  26b01b1c4cd5656bab18d24c548834fb     647
# 2 2020-05-15 03:12:41.480000  30f3653fc176d54e89ac3179c455c6dd     624
# 3 2020-05-15 04:43:08.994000  1528f0eaa027580820ccf0d92a53ad68     579
# 4 2020-05-15 07:47:17.197000  496ea4f0d4abe264b1bb1b80eb3830c5     572
#
#    18_group  is_mi                             fall_1  \
# 0     181.0    NaN                           Язык SQL
# 1     181.0    NaN  Высокопроизводительные вычисления
# 2     185.0    NaN   Безопасность компьютерных систем
# 3     182.0    NaN        Statistical Learning Theory
# 4     183.0    NaN  Высокопроизводительные вычисления
#
#                               fall_2                         fall_3  \
# 0  Высокопроизводительные вычисления           Матричные вычисления
# 1   Безопасность компьютерных систем                       Язык SQL
# 2               Матричные вычисления  Моделирование временных рядов
# 3  Высокопроизводительные вычисления           Матричные вычисления
# 4   Безопасность компьютерных систем              Теория баз данных
#
#                  spring_1                spring_2             spring_3  \
# 0  Дискретная оптимизация        Численные методы  Машинное обучение 2
# 1  Дискретная оптимизация        Численные методы  Машинное обучение 2
# 2  Дискретная оптимизация     Машинное обучение 2     Численные методы
# 3  Дискретная оптимизация        Численные методы  Машинное обучение 2
# 4       Компьютерные сети  Дискретная оптимизация     Численные методы
#
#   is_first_time  percentile  17_group blended  is_ml_student
# 0            Да    0.183857       NaN     NaN            NaN
# 1           Нет    0.426009       NaN     NaN            NaN
# 2            Да    0.538117       NaN     NaN            NaN
# 3            Да    0.744395       NaN     NaN            NaN
# 4            Да    0.780269       NaN     NaN            NaN

# %% [markdown]
# #### 2. [0.5 балла] Ответьте на вопросы:
# 1. Сколько было заявок из групп 18-го года набора, а сколько из групп 17-го года?
# 2. Есть ли студенты с равными перцентилями?

# %%
print("Заявок из 18-го года:", df["18_group"].count())
print("Заявок из 17-го года:", df["17_group"].count())
# Out:
# Заявок из 18-го года: 223
# Заявок из 17-го года: 138

# %%
df["percentile"].value_counts()
# Out:
# 0.807971    2
# 0.795964    2
# 0.773543    2
# 0.526906    2
# 0.293478    2
#            ..
# 0.560538    1
# 0.843049    1
# 0.385650    1
# 0.739910    1
# 0.369565    1
# Name: percentile, Length: 346, dtype: int64

# %% [markdown]
# Как мы видим - да, такие студенты есть.

# %% [markdown]
# #### 3. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
len(df)
# Out:
# 361

# %%
df.describe()
# Out:
#             rating    18_group  is_mi  percentile    17_group  is_ml_student
# count   361.000000  223.000000   18.0  361.000000  138.000000           57.0
# mean    833.346260  184.520179    1.0    0.497230  173.355072            1.0
# std     266.665103    2.271701    0.0    0.289071    1.795374            0.0
# min     495.000000  181.000000    1.0    0.000000  171.000000            1.0
# 25%     613.000000  183.000000    1.0    0.246637  172.000000            1.0
# 50%     697.000000  185.000000    1.0    0.497758  173.000000            1.0
# 75%    1111.000000  187.000000    1.0    0.746377  175.000000            1.0
# max    1457.000000  188.000000    1.0    0.995516  177.000000            1.0

# %% [markdown]
# Пропуски есть, всего строк 361. Далее в выводе смотрим строку `count` - здесь мы видим количество валидных значений, следовательно, `361 - #quantity` - это число пропусков. Однако это решение нам не особо подходит, так как в учет идут только числовые данные. Попробуем другой подход:

# %%
df.isnull().sum(axis = 0)
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %% [markdown]
# Здесь мы уже явно видим, сколько в каждом столбце невалидных значений.

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
df.dtypes
# Out:
# timestamp        datetime64[ns]
# id                       object
# rating                    int64
# 18_group                float64
# is_mi                   float64
# fall_1                   object
# fall_2                   object
# fall_3                   object
# spring_1                 object
# spring_2                 object
# spring_3                 object
# is_first_time            object
# percentile              float64
# 17_group                float64
# blended                  object
# is_ml_student           float64
# dtype: object

# %%
df = df.fillna({'is_first_time':'', 'blended':''}).fillna(0)
df.isnull().sum(axis = 0)
# Out:
# timestamp        0
# id               0
# rating           0
# 18_group         0
# is_mi            0
# fall_1           0
# fall_2           0
# fall_3           0
# spring_1         0
# spring_2         0
# spring_3         0
# is_first_time    0
# percentile       0
# 17_group         0
# blended          0
# is_ml_student    0
# dtype: int64

# %%
df.head(15)
# Out:
#                     timestamp                                id  rating  \
# 0  2020-05-15 01:12:50.543000  93ff79a51cd602f1dd3028ba2c129503     698
# 1  2020-05-15 02:46:48.066001  26b01b1c4cd5656bab18d24c548834fb     647
# 2  2020-05-15 03:12:41.480000  30f3653fc176d54e89ac3179c455c6dd     624
# 3  2020-05-15 04:43:08.994000  1528f0eaa027580820ccf0d92a53ad68     579
# 4  2020-05-15 07:47:17.197000  496ea4f0d4abe264b1bb1b80eb3830c5     572
# 5  2020-05-15 09:10:18.558000  d0d8ff53ed5b119f9056068e954256c6     591
# 6  2020-05-15 11:42:16.910000  e4caca755ee0bdd711e18fb8084958b5     724
# 7  2020-05-15 12:11:43.252000  8047c18b3c531c6f47931e0744f3e028     566
# 8  2020-05-15 13:21:40.913000  e8b314842f176be9051d14a07cb156cb     618
# 9  2020-05-15 13:29:10.789000  d6c079f1ff869c8c84fa3ed30bd67e0e     733
# 10 2020-05-15 13:46:31.518000  57c331c5a1b473501d86dfd23421bb5c     623
# 11 2020-05-15 14:52:24.210000  3de75278c0cdb78bbe54267f65c67d25     563
# 12 2020-05-15 16:13:05.416000  77c7b37ee521df16ccff23ba50c893d4     735
# 13 2020-05-15 16:19:15.181000  23484c24b8d551a189015750171974cd     734
# 14 2020-05-15 16:46:00.536000  105209181e880d891f19de83b4b1478d     706
#
#     18_group  is_mi                                             fall_1  \
# 0      181.0    0.0                                           Язык SQL
# 1      181.0    0.0                  Высокопроизводительные вычисления
# 2      185.0    0.0                   Безопасность компьютерных систем
# 3      182.0    0.0                        Statistical Learning Theory
# 4      183.0    0.0                  Высокопроизводительные вычисления
# 5      187.0    0.0                                           Язык SQL
# 6      181.0    0.0                        Statistical Learning Theory
# 7      187.0    0.0                                           Язык SQL
# 8      181.0    0.0                                           Язык SQL
# 9      181.0    0.0                                  Теория баз данных
# 10     186.0    0.0  Принятие решений в условиях риска и неопределё...
# 11     187.0    0.0                                           Язык SQL
# 12     183.0    0.0                  Высокопроизводительные вычисления
# 13     183.0    0.0                  Высокопроизводительные вычисления
# 14     183.0    0.0                   Безопасность компьютерных систем
#
#                                fall_2  \
# 0   Высокопроизводительные вычисления
# 1    Безопасность компьютерных систем
# 2                Матричные вычисления
# 3   Высокопроизводительные вычисления
# 4    Безопасность компьютерных систем
# 5         Statistical Learning Theory
# 6    Безопасность компьютерных систем
# 7                   Теория баз данных
# 8                   Теория баз данных
# 9   Высокопроизводительные вычисления
# 10      Моделирование временных рядов
# 11                  Теория баз данных
# 12                           Язык SQL
# 13   Безопасность компьютерных систем
# 14      Моделирование временных рядов
#
#                                                fall_3  \
# 0                                Матричные вычисления
# 1                                            Язык SQL
# 2                       Моделирование временных рядов
# 3                                Матричные вычисления
# 4                                   Теория баз данных
# 5     Сбор и обработка данных с помощью краудсорсинга
# 6                       Моделирование временных рядов
# 7                    Безопасность компьютерных систем
# 8                                Матричные вычисления
# 9     Сбор и обработка данных с помощью краудсорсинга
# 10                               Матричные вычисления
# 11    Сбор и обработка данных с помощью краудсорсинга
# 12                   Безопасность компьютерных систем
# 13                                  Теория баз данных
# 14  Принятие решений в условиях риска и неопределё...
#
#                                        spring_1  \
# 0                        Дискретная оптимизация
# 1                        Дискретная оптимизация
# 2                        Дискретная оптимизация
# 3                        Дискретная оптимизация
# 4                             Компьютерные сети
# 5   Промышленное программирование на языке Java
# 6                              Численные методы
# 7   Промышленное программирование на языке Java
# 8   Промышленное программирование на языке Java
# 9    Дополнительные главы прикладной статистики
# 10                      Анализ данных в бизнесе
# 11  Промышленное программирование на языке Java
# 12                            Компьютерные сети
# 13                            Компьютерные сети
# 14                      Анализ данных в бизнесе
#
#                                        spring_2                 spring_3  \
# 0                              Численные методы      Машинное обучение 2
# 1                              Численные методы      Машинное обучение 2
# 2                           Машинное обучение 2         Численные методы
# 3                              Численные методы      Машинное обучение 2
# 4                        Дискретная оптимизация         Численные методы
# 5                              Численные методы   Дискретная оптимизация
# 6   Промышленное программирование на языке Java      Машинное обучение 2
# 7                             Компьютерные сети   Дискретная оптимизация
# 8                             Компьютерные сети   Дискретная оптимизация
# 9                       Анализ данных в бизнесе         Численные методы
# 10                             Численные методы      Машинное обучение 2
# 11                           Системы баз данных  Анализ данных в бизнесе
# 12  Промышленное программирование на языке Java      Машинное обучение 2
# 13                       Дискретная оптимизация      Машинное обучение 2
# 14                       Дискретная оптимизация       Системы баз данных
#
#    is_first_time  percentile  17_group blended  is_ml_student
# 0             Да    0.183857       0.0                    0.0
# 1            Нет    0.426009       0.0                    0.0
# 2             Да    0.538117       0.0                    0.0
# 3             Да    0.744395       0.0                    0.0
# 4             Да    0.780269       0.0                    0.0
# 5             Да    0.690583       0.0                    0.0
# 6             Да    0.103139       0.0                    0.0
# 7             Да    0.802691       0.0                    0.0
# 8             Да    0.565022       0.0                    0.0
# 9             Да    0.085202       0.0                    1.0
# 10            Да    0.542601       0.0                    0.0
# 11            Да    0.811659       0.0                    0.0
# 12            Да    0.076233       0.0                    0.0
# 13            Да    0.080717       0.0                    0.0
# 14            Да    0.152466       0.0                    1.0

# %% [markdown]
# #### 4. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Есть ли в ней ответы "Нет"? Сколько их?
#
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. <i>Обращения со значением "Нет" в <code>is_first_time</code> могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
df['is_first_time'].value_counts()
# Out:
# Да     308
# Нет     51
#          2
# Name: is_first_time, dtype: int64

# %% [markdown]
# "Нет" - 51.

# %%
df['id'].value_counts()
# Out:
# f8fab519d78047712c06798c8b7fe38f    2
# 8aa0f1b7331b49464174b02cd693be52    2
# 5c49473012411a1eee72f8ea63767adf    2
# a65d50ef4fadfac64508a54e972d8623    2
# 9a66d84568b8017d98eb2e678b57296b    2
#                                    ..
# 6cd7de3774f07c65e44668cdf7e987b6    1
# 2f8a48924249d2231659183d7654ed33    1
# ecc19831d7abd064f0488a9af2521920    1
# a19f36ae8465cac527e8ce7b6ebf1213    1
# f2d210ace25a841e1e58036b257d5d47    1
# Name: id, Length: 347, dtype: int64

# %%
df.sort_values(by=['id', 'timestamp'], inplace=True)
df.tail(20)
# Out:
#                      timestamp                                id  rating  \
# 163 2020-05-18 22:09:23.107000  f81cc449798c2d8971612dc9a749ad2a     637
# 49  2020-05-17 16:39:53.941000  f8c83b338162bb41af2851b5e62f84d0     547
# 141 2020-05-18 21:34:22.233000  f8fab519d78047712c06798c8b7fe38f     561
# 150 2020-05-18 21:49:22.232999  f8fab519d78047712c06798c8b7fe38f     561
# 352 2020-05-18 23:59:20.831000  f93afd8e92c336b471aa3bbbc579aefe    1298
# 193 2020-05-18 23:38:11.238001  f941beb89ecc5c59076bcfa79691116c     610
# 320 2020-05-18 22:14:40.670000  f98ac9a12b43a53c0fa44491cb56890c    1147
# 72  2020-05-18 14:44:19.585999  fa4860bc719aadedbb00ba027067a8b7     642
# 309 2020-05-18 21:09:04.370000  fa61e55c68763160d0fffe57dab37af9    1121
# 119 2020-05-18 20:34:07.220000  fc2c60b8004aa91bc272df84628621ff     639
# 248 2020-05-17 03:06:53.984000  fc833a2815fa010d53b0047244438d9d    1250
# 254 2020-05-17 14:43:12.815001  fc8b84c5df1ea8bf6e5da51945124d57    1204
# 89  2020-05-18 18:01:52.603999  fd784637a19d65bbe5b07d6efac5a05d     625
# 292 2020-05-18 18:14:38.722000  fe631bea98b075dd781e11df3987533b    1085
# 135 2020-05-18 21:19:50.620000  feb53dcdd28fff9dc4a981c3419fea6f     521
# 281 2020-05-18 14:29:51.415000  fecff7bd30995d16b59fb392d47b3760    1278
# 103 2020-05-18 19:23:23.735001  ff549c331d45453052f28ad2614afda9     723
# 307 2020-05-18 21:00:45.274000  ffc04c64d068f8d85e4dc44e7f297ecc    1163
# 129 2020-05-18 21:12:02.445001  ffc58d371e2f52e1c7f45d49d3d629d0     659
# 139 2020-05-18 21:27:02.445000  ffc58d371e2f52e1c7f45d49d3d629d0     659
#
#      18_group  is_mi                                           fall_1  \
# 163     186.0    0.0                Высокопроизводительные вычисления
# 49      185.0    0.0                                Теория баз данных
# 141     185.0    1.0                                Теория баз данных
# 150     185.0    1.0                    Моделирование временных рядов
# 352       0.0    0.0                Высокопроизводительные вычисления
# 193     186.0    1.0                                Теория баз данных
# 320       0.0    0.0            Байесовские методы машинного обучения
# 72      187.0    0.0                 Безопасность компьютерных систем
# 309       0.0    0.0                Анализ неструктурированных данных
# 119     183.0    0.0                                         Язык SQL
# 248       0.0    0.0                      Statistical Learning Theory
# 254       0.0    0.0            Байесовские методы машинного обучения
# 89      182.0    0.0                 Безопасность компьютерных систем
# 292       0.0    0.0                      Statistical Learning Theory
# 135     186.0    1.0                 Безопасность компьютерных систем
# 281       0.0    0.0                Анализ неструктурированных данных
# 103     182.0    0.0                    Моделирование временных рядов
# 307       0.0    0.0            Байесовские методы машинного обучения
# 129     187.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 139     187.0    0.0                             Матричные вычисления
#
#                                                 fall_2  \
# 163                                           Язык SQL
# 49                                            Язык SQL
# 141                      Моделирование временных рядов
# 150                                  Теория баз данных
# 352    Сбор и обработка данных с помощью краудсорсинга
# 193  Принятие решений в условиях риска и неопределё...
# 320                  Анализ неструктурированных данных
# 72                   Высокопроизводительные вычисления
# 309                   Безопасность компьютерных систем
# 119    Сбор и обработка данных с помощью краудсорсинга
# 248              Байесовские методы машинного обучения
# 254                  Высокопроизводительные вычисления
# 89                         Statistical Learning Theory
# 292                      Моделирование временных рядов
# 135                                           Язык SQL
# 281                   Безопасность компьютерных систем
# 103                                  Теория баз данных
# 307                        Statistical Learning Theory
# 129                               Матричные вычисления
# 139    Сбор и обработка данных с помощью краудсорсинга
#
#                                               fall_3  \
# 163                    Моделирование временных рядов
# 49                  Безопасность компьютерных систем
# 141                                         Язык SQL
# 150                                         Язык SQL
# 352                      Statistical Learning Theory
# 193  Сбор и обработка данных с помощью краудсорсинга
# 320  Сбор и обработка данных с помощью краудсорсинга
# 72                                          Язык SQL
# 309  Сбор и обработка данных с помощью краудсорсинга
# 119                      Statistical Learning Theory
# 248                    Моделирование временных рядов
# 254                Анализ неструктурированных данных
# 89                              Матричные вычисления
# 292                Высокопроизводительные вычисления
# 135  Сбор и обработка данных с помощью краудсорсинга
# 281            Байесовские методы машинного обучения
# 103                             Матричные вычисления
# 307             Глубинное обучение в обработке звука
# 129                    Моделирование временных рядов
# 139                    Моделирование временных рядов
#
#                                               spring_1  \
# 163                                  Компьютерные сети
# 49         Промышленное программирование на языке Java
# 141        Промышленное программирование на языке Java
# 150        Промышленное программирование на языке Java
# 352               Методы сжатия и передачи медиаданных
# 193        Промышленное программирование на языке Java
# 320                           Обучение с подкреплением
# 72                                   Компьютерные сети
# 309                           Обучение с подкреплением
# 119                                 Системы баз данных
# 248                              Символьные вычисления
# 254  Проектирование и разработка высоконагруженных ...
# 89                                 Машинное обучение 2
# 292                              Символьные вычисления
# 135        Промышленное программирование на языке Java
# 281                           Обучение с подкреплением
# 103                                   Численные методы
# 307                           Обучение с подкреплением
# 129                                 Системы баз данных
# 139                                 Системы баз данных
#
#                                               spring_2  \
# 163                            Анализ данных в бизнесе
# 49                                   Компьютерные сети
# 141                                Машинное обучение 2
# 150                                Машинное обучение 2
# 352  Проектирование и разработка высоконагруженных ...
# 193                            Анализ данных в бизнесе
# 320                                Компьютерное зрение
# 72         Промышленное программирование на языке Java
# 309                                Компьютерное зрение
# 119                                Машинное обучение 2
# 248                                Компьютерное зрение
# 254                           Обучение с подкреплением
# 89                              Дискретная оптимизация
# 292                             Конфликты и кооперация
# 135                            Анализ данных в бизнесе
# 281                                Компьютерное зрение
# 103                            Анализ данных в бизнесе
# 307            Генеративные модели в машинном обучении
# 129        Промышленное программирование на языке Java
# 139        Промышленное программирование на языке Java
#
#                                         spring_3 is_first_time  percentile  \
# 163                       Дискретная оптимизация           Нет    0.470852
# 49                        Дискретная оптимизация            Да    0.878924
# 141                            Компьютерные сети            Да    0.822870
# 150                            Компьютерные сети           Нет    0.822870
# 352                       Конфликты и кооперация            Да    0.057971
# 193                           Системы баз данных            Да    0.605381
# 320      Генеративные модели в машинном обучении            Да    0.528986
# 72                        Дискретная оптимизация            Да    0.448430
# 309      Генеративные модели в машинном обучении            Да    0.630435
# 119                      Анализ данных в бизнесе           Нет    0.461883
# 248                       Конфликты и кооперация            Да    0.144928
# 254                          Компьютерное зрение            Да    0.304348
# 89                             Компьютерные сети            Да    0.533632
# 292                             Численные методы            Да    0.775362
# 135                          Машинное обучение 2           Нет    0.968610
# 281      Генеративные модели в машинном обучении            Да    0.094203
# 103  Промышленное программирование на языке Java            Да    0.107623
# 307                          Компьютерное зрение           Нет    0.471014
# 129   Дополнительные главы прикладной статистики            Да    0.369955
# 139   Дополнительные главы прикладной статистики           Нет    0.369955
#
#      17_group                                blended  is_ml_student
# 163       0.0                                                   0.0
# 49        0.0                                                   0.0
# 141       0.0                                                   0.0
# 150       0.0                                                   0.0
# 352     175.0                                 DevOps            0.0
# 193       0.0                                                   0.0
# 320     171.0                                 DevOps            0.0
# 72        0.0                                                   0.0
# 309     172.0                                 DevOps            0.0
# 119       0.0                                                   1.0
# 248     173.0  Введение в дифференциальную геометрию            0.0
# 254     171.0                                 DevOps            0.0
# 89        0.0                                                   0.0
# 292     173.0  Введение в дифференциальную геометрию            0.0
# 135       0.0                                                   0.0
# 281     171.0                                 DevOps            0.0
# 103       0.0                                                   0.0
# 307     171.0         Соревновательный анализ данных            0.0
# 129       0.0                                                   1.0
# 139       0.0                                                   1.0

# %%
# https://coderoad.ru/51659207/Удалить-дубликаты-из-серии-pandas-на-основе-условия
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html
df.drop_duplicates(subset=['id'], keep='last', inplace=True)
df.tail(20)
# Out:
#                      timestamp                                id  rating  \
# 101 2020-05-18 19:09:00.945001  f736e00dc03850c59649e77149895d5a     652
# 206 2020-05-18 23:59:29.314000  f7f123322f77fd451a30ed4979c323fc     578
# 163 2020-05-18 22:09:23.107000  f81cc449798c2d8971612dc9a749ad2a     637
# 49  2020-05-17 16:39:53.941000  f8c83b338162bb41af2851b5e62f84d0     547
# 150 2020-05-18 21:49:22.232999  f8fab519d78047712c06798c8b7fe38f     561
# 352 2020-05-18 23:59:20.831000  f93afd8e92c336b471aa3bbbc579aefe    1298
# 193 2020-05-18 23:38:11.238001  f941beb89ecc5c59076bcfa79691116c     610
# 320 2020-05-18 22:14:40.670000  f98ac9a12b43a53c0fa44491cb56890c    1147
# 72  2020-05-18 14:44:19.585999  fa4860bc719aadedbb00ba027067a8b7     642
# 309 2020-05-18 21:09:04.370000  fa61e55c68763160d0fffe57dab37af9    1121
# 119 2020-05-18 20:34:07.220000  fc2c60b8004aa91bc272df84628621ff     639
# 248 2020-05-17 03:06:53.984000  fc833a2815fa010d53b0047244438d9d    1250
# 254 2020-05-17 14:43:12.815001  fc8b84c5df1ea8bf6e5da51945124d57    1204
# 89  2020-05-18 18:01:52.603999  fd784637a19d65bbe5b07d6efac5a05d     625
# 292 2020-05-18 18:14:38.722000  fe631bea98b075dd781e11df3987533b    1085
# 135 2020-05-18 21:19:50.620000  feb53dcdd28fff9dc4a981c3419fea6f     521
# 281 2020-05-18 14:29:51.415000  fecff7bd30995d16b59fb392d47b3760    1278
# 103 2020-05-18 19:23:23.735001  ff549c331d45453052f28ad2614afda9     723
# 307 2020-05-18 21:00:45.274000  ffc04c64d068f8d85e4dc44e7f297ecc    1163
# 139 2020-05-18 21:27:02.445000  ffc58d371e2f52e1c7f45d49d3d629d0     659
#
#      18_group  is_mi                                 fall_1  \
# 101     186.0    0.0      Высокопроизводительные вычисления
# 206     185.0    0.0                               Язык SQL
# 163     186.0    0.0      Высокопроизводительные вычисления
# 49      185.0    0.0                      Теория баз данных
# 150     185.0    1.0          Моделирование временных рядов
# 352       0.0    0.0      Высокопроизводительные вычисления
# 193     186.0    1.0                      Теория баз данных
# 320       0.0    0.0  Байесовские методы машинного обучения
# 72      187.0    0.0       Безопасность компьютерных систем
# 309       0.0    0.0      Анализ неструктурированных данных
# 119     183.0    0.0                               Язык SQL
# 248       0.0    0.0            Statistical Learning Theory
# 254       0.0    0.0  Байесовские методы машинного обучения
# 89      182.0    0.0       Безопасность компьютерных систем
# 292       0.0    0.0            Statistical Learning Theory
# 135     186.0    1.0       Безопасность компьютерных систем
# 281       0.0    0.0      Анализ неструктурированных данных
# 103     182.0    0.0          Моделирование временных рядов
# 307       0.0    0.0  Байесовские методы машинного обучения
# 139     187.0    0.0                   Матричные вычисления
#
#                                                 fall_2  \
# 101                                           Язык SQL
# 206                   Безопасность компьютерных систем
# 163                                           Язык SQL
# 49                                            Язык SQL
# 150                                  Теория баз данных
# 352    Сбор и обработка данных с помощью краудсорсинга
# 193  Принятие решений в условиях риска и неопределё...
# 320                  Анализ неструктурированных данных
# 72                   Высокопроизводительные вычисления
# 309                   Безопасность компьютерных систем
# 119    Сбор и обработка данных с помощью краудсорсинга
# 248              Байесовские методы машинного обучения
# 254                  Высокопроизводительные вычисления
# 89                         Statistical Learning Theory
# 292                      Моделирование временных рядов
# 135                                           Язык SQL
# 281                   Безопасность компьютерных систем
# 103                                  Теория баз данных
# 307                        Statistical Learning Theory
# 139    Сбор и обработка данных с помощью краудсорсинга
#
#                                               fall_3  \
# 101                 Безопасность компьютерных систем
# 206                                Теория баз данных
# 163                    Моделирование временных рядов
# 49                  Безопасность компьютерных систем
# 150                                         Язык SQL
# 352                      Statistical Learning Theory
# 193  Сбор и обработка данных с помощью краудсорсинга
# 320  Сбор и обработка данных с помощью краудсорсинга
# 72                                          Язык SQL
# 309  Сбор и обработка данных с помощью краудсорсинга
# 119                      Statistical Learning Theory
# 248                    Моделирование временных рядов
# 254                Анализ неструктурированных данных
# 89                              Матричные вычисления
# 292                Высокопроизводительные вычисления
# 135  Сбор и обработка данных с помощью краудсорсинга
# 281            Байесовские методы машинного обучения
# 103                             Матричные вычисления
# 307             Глубинное обучение в обработке звука
# 139                    Моделирование временных рядов
#
#                                               spring_1  \
# 101                                Машинное обучение 2
# 206        Промышленное программирование на языке Java
# 163                                  Компьютерные сети
# 49         Промышленное программирование на языке Java
# 150        Промышленное программирование на языке Java
# 352               Методы сжатия и передачи медиаданных
# 193        Промышленное программирование на языке Java
# 320                           Обучение с подкреплением
# 72                                   Компьютерные сети
# 309                           Обучение с подкреплением
# 119                                 Системы баз данных
# 248                              Символьные вычисления
# 254  Проектирование и разработка высоконагруженных ...
# 89                                 Машинное обучение 2
# 292                              Символьные вычисления
# 135        Промышленное программирование на языке Java
# 281                           Обучение с подкреплением
# 103                                   Численные методы
# 307                           Обучение с подкреплением
# 139                                 Системы баз данных
#
#                                               spring_2  \
# 101        Промышленное программирование на языке Java
# 206                                  Компьютерные сети
# 163                            Анализ данных в бизнесе
# 49                                   Компьютерные сети
# 150                                Машинное обучение 2
# 352  Проектирование и разработка высоконагруженных ...
# 193                            Анализ данных в бизнесе
# 320                                Компьютерное зрение
# 72         Промышленное программирование на языке Java
# 309                                Компьютерное зрение
# 119                                Машинное обучение 2
# 248                                Компьютерное зрение
# 254                           Обучение с подкреплением
# 89                              Дискретная оптимизация
# 292                             Конфликты и кооперация
# 135                            Анализ данных в бизнесе
# 281                                Компьютерное зрение
# 103                            Анализ данных в бизнесе
# 307            Генеративные модели в машинном обучении
# 139        Промышленное программирование на языке Java
#
#                                         spring_3 is_first_time  percentile  \
# 101                             Численные методы            Да    0.403587
# 206                           Системы баз данных           Нет    0.748879
# 163                       Дискретная оптимизация           Нет    0.470852
# 49                        Дискретная оптимизация            Да    0.878924
# 150                            Компьютерные сети           Нет    0.822870
# 352                       Конфликты и кооперация            Да    0.057971
# 193                           Системы баз данных            Да    0.605381
# 320      Генеративные модели в машинном обучении            Да    0.528986
# 72                        Дискретная оптимизация            Да    0.448430
# 309      Генеративные модели в машинном обучении            Да    0.630435
# 119                      Анализ данных в бизнесе           Нет    0.461883
# 248                       Конфликты и кооперация            Да    0.144928
# 254                          Компьютерное зрение            Да    0.304348
# 89                             Компьютерные сети            Да    0.533632
# 292                             Численные методы            Да    0.775362
# 135                          Машинное обучение 2           Нет    0.968610
# 281      Генеративные модели в машинном обучении            Да    0.094203
# 103  Промышленное программирование на языке Java            Да    0.107623
# 307                          Компьютерное зрение           Нет    0.471014
# 139   Дополнительные главы прикладной статистики           Нет    0.369955
#
#      17_group                                blended  is_ml_student
# 101       0.0                                                   0.0
# 206       0.0                                                   0.0
# 163       0.0                                                   0.0
# 49        0.0                                                   0.0
# 150       0.0                                                   0.0
# 352     175.0                                 DevOps            0.0
# 193       0.0                                                   0.0
# 320     171.0                                 DevOps            0.0
# 72        0.0                                                   0.0
# 309     172.0                                 DevOps            0.0
# 119       0.0                                                   1.0
# 248     173.0  Введение в дифференциальную геометрию            0.0
# 254     171.0                                 DevOps            0.0
# 89        0.0                                                   0.0
# 292     173.0  Введение в дифференциальную геометрию            0.0
# 135       0.0                                                   0.0
# 281     171.0                                 DevOps            0.0
# 103       0.0                                                   0.0
# 307     171.0         Соревновательный анализ данных            0.0
# 139       0.0                                                   1.0

# %% [markdown]
# Что я сделал: сначала отсортировал по времени заявки, затем по айди - вышло так, что заявки одного и того же студента были рядом друг с другом, что позволило воспользоваться функцией, удаляющей дубликаты с возможностью сохранения последнего. Так как мы сортировали по времени, после удаления у нас остались лишь последние записи.

# %% [markdown]
# #### 5. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из курсов собрались студенты с самым высоким средним рейтингом?

# %%
df['blended'].value_counts()
# Out:
#                                          213
# DevOps                                    87
# Соревновательный анализ данных            32
# Введение в дифференциальную геометрию     15
# Name: blended, dtype: int64

# %% [markdown]
# Вот такие курсы выбирали студенты, больше всего пошло на DevOps.

# %%
from numpy import mean as nmean
grouped = pd.pivot_table(data=df,index=['blended'],aggfunc={'rating':nmean})
grouped
# Out:
#                                             rating
# blended
#                                         633.901408
# DevOps                                 1154.172414
# Введение в дифференциальную геометрию  1210.733333
# Соревновательный анализ данных         1144.218750

# %% [markdown]
# Если я правильно понял задание, то на "Введении в дифференциальную геометрию" рейтинг студентов выше всех. Если же я неправильно понял задание, и требовалось посмотреть, на какие курсы записались топовые студенты, можно сделать так:

# %%
df.sort_values(by=['percentile'])[['percentile', 'blended']].head(20)
# Out:
#      percentile                                blended
# 231    0.000000  Введение в дифференциальную геометрию
# 80     0.000000
# 91     0.004484
# 273    0.007246                                 DevOps
# 19     0.008969
# 94     0.013453
# 323    0.014493                                 DevOps
# 158    0.017937
# 250    0.021739         Соревновательный анализ данных
# 84     0.022422
# 210    0.026906
# 267    0.028986                                 DevOps
# 93     0.031390
# 85     0.035874
# 347    0.036232                                 DevOps
# 48     0.040359
# 327    0.043478                                 DevOps
# 26     0.044843
# 209    0.049327
# 305    0.050725  Введение в дифференциальную геометрию

# %% [markdown]
# А здесь уже картина другая - DevOps в выигрыше, так как большинство лучших студентов пошли именно туда.

# %% [markdown]
# #### 6. [1 балл] Выясните, есть ли в данных студенты с абсолютно одинаковыми предпочтениями по всем курсам (не забудьте учесть blended-курсы для четверокурсников). Сколько таких наборов, которые взяли несколько студентов? Выведите их все вместе с количеством выбравших их студентов.
#
# <i>Предпочтения двух студентов считаются абсолютно одинаковыми, если выбранные ими дисциплины имеют одинаковый приоритет.</i>

# %%
dfg = df.groupby(['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'], as_index=False).size()
dfg.head()
# Out:
#                         fall_1                                 fall_2  \
# 0  Statistical Learning Theory      Анализ неструктурированных данных
# 1  Statistical Learning Theory      Анализ неструктурированных данных
# 2  Statistical Learning Theory  Байесовские методы машинного обучения
# 3  Statistical Learning Theory  Байесовские методы машинного обучения
# 4  Statistical Learning Theory  Байесовские методы машинного обучения
#
#                                             fall_3  \
# 0  Сбор и обработка данных с помощью краудсорсинга
# 1  Сбор и обработка данных с помощью краудсорсинга
# 2                 Безопасность компьютерных систем
# 3                Высокопроизводительные вычисления
# 4                    Моделирование временных рядов
#
#                                             spring_1                spring_2  \
# 0                           Обучение с подкреплением  Конфликты и кооперация
# 1                           Обучение с подкреплением  Конфликты и кооперация
# 2  Проектирование и разработка высоконагруженных ...     Компьютерное зрение
# 3                              Символьные вычисления     Компьютерное зрение
# 4                              Символьные вычисления     Компьютерное зрение
#
#                                             spring_3  \
# 0                                Компьютерное зрение
# 1                                Компьютерное зрение
# 2                              Символьные вычисления
# 3  Проектирование и разработка высоконагруженных ...
# 4                             Конфликты и кооперация
#
#                                  blended  size
# 0                                 DevOps     2
# 1         Соревновательный анализ данных     1
# 2  Введение в дифференциальную геометрию     1
# 3  Введение в дифференциальную геометрию     1
# 4  Введение в дифференциальную геометрию     1

# %% [markdown]
# Вот такие вот наборы:

# %%
dfg.sort_values('size', ascending=False)[dfg['size'] >= 2]
# Out:
# C:\Users\Oleg\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                               fall_1  \
# 102                 Безопасность компьютерных систем
# 72                  Безопасность компьютерных систем
# 0                        Statistical Learning Theory
# 313                                         Язык SQL
# 155                 Безопасность компьютерных систем
# 184                Высокопроизводительные вычисления
# 137                 Безопасность компьютерных систем
# 201                Высокопроизводительные вычисления
# 113                 Безопасность компьютерных систем
# 105                 Безопасность компьютерных систем
# 244                    Моделирование временных рядов
# 62             Байесовские методы машинного обучения
# 60             Байесовские методы машинного обучения
# 292  Сбор и обработка данных с помощью краудсорсинга
# 84                  Безопасность компьютерных систем
#
#                                               fall_2  \
# 102                Высокопроизводительные вычисления
# 72                       Statistical Learning Theory
# 0                  Анализ неструктурированных данных
# 313                Высокопроизводительные вычисления
# 155                                Теория баз данных
# 184                 Безопасность компьютерных систем
# 137  Сбор и обработка данных с помощью краудсорсинга
# 201  Сбор и обработка данных с помощью краудсорсинга
# 113                             Матричные вычисления
# 105                Высокопроизводительные вычисления
# 244  Сбор и обработка данных с помощью краудсорсинга
# 62                 Анализ неструктурированных данных
# 60                 Анализ неструктурированных данных
# 292                                         Язык SQL
# 84                 Высокопроизводительные вычисления
#
#                                               fall_3  \
# 102                                         Язык SQL
# 72                              Матричные вычисления
# 0    Сбор и обработка данных с помощью краудсорсинга
# 313                                Теория баз данных
# 155                                         Язык SQL
# 184  Сбор и обработка данных с помощью краудсорсинга
# 137                             Матричные вычисления
# 201                    Моделирование временных рядов
# 113                    Моделирование временных рядов
# 105                                         Язык SQL
# 244                 Безопасность компьютерных систем
# 62   Сбор и обработка данных с помощью краудсорсинга
# 60              Глубинное обучение в обработке звука
# 292                                Теория баз данных
# 84                 Анализ неструктурированных данных
#
#                                               spring_1  \
# 102                                  Компьютерные сети
# 72                              Дискретная оптимизация
# 0                             Обучение с подкреплением
# 313                                  Компьютерные сети
# 155                                Машинное обучение 2
# 184  Проектирование и разработка высоконагруженных ...
# 137                                  Компьютерные сети
# 201  Проектирование и разработка высоконагруженных ...
# 113        Промышленное программирование на языке Java
# 105        Промышленное программирование на языке Java
# 244                                  Компьютерные сети
# 62                            Обучение с подкреплением
# 60                            Обучение с подкреплением
# 292        Промышленное программирование на языке Java
# 84   Проектирование и разработка высоконагруженных ...
#
#                                         spring_2  \
# 102  Промышленное программирование на языке Java
# 72   Промышленное программирование на языке Java
# 0                         Конфликты и кооперация
# 313  Промышленное программирование на языке Java
# 155                            Компьютерные сети
# 184         Методы сжатия и передачи медиаданных
# 137  Промышленное программирование на языке Java
# 201         Методы сжатия и передачи медиаданных
# 113                            Компьютерные сети
# 105                            Компьютерные сети
# 244   Дополнительные главы прикладной статистики
# 62                           Компьютерное зрение
# 60       Генеративные модели в машинном обучении
# 292                          Машинное обучение 2
# 84          Методы сжатия и передачи медиаданных
#
#                                         spring_3 blended  size
# 102                       Дискретная оптимизация             3
# 72    Дополнительные главы прикладной статистики             3
# 0                            Компьютерное зрение  DevOps     2
# 313                       Дискретная оптимизация             2
# 155  Промышленное программирование на языке Java             2
# 184                          Компьютерное зрение  DevOps     2
# 137                      Анализ данных в бизнесе             2
# 201         Методы сжатия и передачи медиаданных  DevOps     2
# 113                       Дискретная оптимизация             2
# 105                           Системы баз данных             2
# 244                           Системы баз данных             2
# 62       Генеративные модели в машинном обучении  DevOps     2
# 60                           Компьютерное зрение  DevOps     2
# 292                            Компьютерные сети             2
# 84                        Конфликты и кооперация  DevOps     2

# %% [markdown]
# #### 7. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
y18 = set(np.unique(df[df['18_group'] >= 180][['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3']].values).tolist())
y17 = set(np.unique(df[df['17_group'] >= 170][['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3']].values).tolist())
print(y18, '\n\n', y17)
# Out:
# {'Теория баз данных', 'Компьютерные сети', 'Моделирование временных рядов', 'Численные методы', 'Дискретная оптимизация', 'Промышленное программирование на языке Java', 'Матричные вычисления', 'Язык SQL', 'Принятие решений в условиях риска и неопределённости', 'Системы баз данных', 'Дополнительные главы прикладной статистики', 'Сбор и обработка данных с помощью краудсорсинга', 'Анализ данных в бизнесе', 'Statistical Learning Theory', 'Безопасность компьютерных систем', 'Машинное обучение 2', 'Высокопроизводительные вычисления'}
#
#  {'Глубинное обучение в обработке звука', 'Компьютерное зрение', 'Обучение с подкреплением', 'Конфликты и кооперация', 'Проектирование и разработка высоконагруженных сервисов', 'Моделирование временных рядов', 'Символьные вычисления', 'Анализ неструктурированных данных', 'Численные методы', 'Байесовские методы машинного обучения', 'Методы сжатия и передачи медиаданных', 'Генеративные модели в машинном обучении', 'Сбор и обработка данных с помощью краудсорсинга', 'Принятие решений в условиях риска и неопределённости', 'Statistical Learning Theory', 'Безопасность компьютерных систем', 'Высокопроизводительные вычисления'}

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
# Только за 17 год
y17 - (y17 & y18)
# Out:
# {'Анализ неструктурированных данных',
#  'Байесовские методы машинного обучения',
#  'Генеративные модели в машинном обучении',
#  'Глубинное обучение в обработке звука',
#  'Компьютерное зрение',
#  'Конфликты и кооперация',
#  'Методы сжатия и передачи медиаданных',
#  'Обучение с подкреплением',
#  'Проектирование и разработка высоконагруженных сервисов',
#  'Символьные вычисления'}

# %%
# Только за 18 год
y18 - (y17 & y18)
# Out:
# {'Анализ данных в бизнесе',
#  'Дискретная оптимизация',
#  'Дополнительные главы прикладной статистики',
#  'Компьютерные сети',
#  'Матричные вычисления',
#  'Машинное обучение 2',
#  'Промышленное программирование на языке Java',
#  'Системы баз данных',
#  'Теория баз данных',
#  'Язык SQL'}

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Полезные строчки:
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# #### 8. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
# https://ru.stackoverflow.com/questions/949501/Как-сгруппировать-по-дню-и-посчитать-среднее-значение-столбца
dfg = df.groupby(pd.Grouper(key='timestamp', freq='D'))['rating'].mean().reset_index()
dfg.rename(columns={'timestamp':'day'}, inplace=True)
dfg.head()
# Out:
#          day       rating
# 0 2020-05-14  1160.277778
# 1 2020-05-15   719.866667
# 2 2020-05-16   736.400000
# 3 2020-05-17   915.027027
# 4 2020-05-18   827.352679

# %%
dfg.dtypes
# Out:
# day       datetime64[ns]
# rating           float64
# dtype: object

# %%
# https://stackoverflow.com/questions/19502506/convert-numpy-datetime64-to-string-object-in-python
dfg['day'] = dfg['day'].astype(str).str[-2:]
dfg.dtypes
# Out:
# day        object
# rating    float64
# dtype: object

# %%
dfg.head()
# Out:
#   day       rating
# 0  14  1160.277778
# 1  15   719.866667
# 2  16   736.400000
# 3  17   915.027027
# 4  18   827.352679

# %%
import seaborn as sns

fig, ax = plt.subplots()
sns.barplot(x='day', y='rating', data=dfg)
plt.title('Day - Mean Rating')
plt.show()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
fig.savefig('bar_1.pdf')

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Алгоритм распределения студентов по курсам:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# Обращаем ваше внимание на следующие детали:
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. <i>Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются. Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо</i>.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то на усмотрение проверяющего могут быть добавлены бонусные баллы. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * три столбца: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * Формат csv: для сохранения воспользуйтесь df.to_csv('solution.csv', index=None)
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * У студентов 18-го года номера групп соответствуют номерам до распределения по специализациям.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert df.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert df.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %%
df.sort_values('percentile', inplace=True)
df.drop('is_first_time', axis=1, inplace=True)

# %%
df.head()
# Out:
#                      timestamp                                id  rating  \
# 231 2020-05-14 21:52:43.844001  3a7326c9e355a67d3805824ca34c4bc5    1457
# 80  2020-05-18 17:09:23.589000  3e106aaef8b24dbb01319c73e14c2936     784
# 91  2020-05-18 18:03:57.347000  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722000  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550000  86d929f6fd741e56e93cee5900298849     761
#
#      18_group  is_mi                                           fall_1  \
# 231       0.0    0.0                      Statistical Learning Theory
# 80      182.0    0.0                 Безопасность компьютерных систем
# 91      182.0    0.0                             Матричные вычисления
# 273       0.0    0.0                Высокопроизводительные вычисления
# 19      181.0    0.0  Сбор и обработка данных с помощью краудсорсинга
#
#                                               fall_2  \
# 231                Высокопроизводительные вычисления
# 80                       Statistical Learning Theory
# 91                  Безопасность компьютерных систем
# 273  Сбор и обработка данных с помощью краудсорсинга
# 19   Сбор и обработка данных с помощью краудсорсинга
#
#                                               fall_3  \
# 231                      Statistical Learning Theory
# 80                              Матричные вычисления
# 91                       Statistical Learning Theory
# 273                    Моделирование временных рядов
# 19   Сбор и обработка данных с помощью краудсорсинга
#
#                                               spring_1  \
# 231                              Символьные вычисления
# 80                              Дискретная оптимизация
# 91                              Дискретная оптимизация
# 273  Проектирование и разработка высоконагруженных ...
# 19          Дополнительные главы прикладной статистики
#
#                                         spring_2  \
# 231                             Численные методы
# 80   Промышленное программирование на языке Java
# 91    Дополнительные главы прикладной статистики
# 273         Методы сжатия и передачи медиаданных
# 19    Дополнительные главы прикладной статистики
#
#                                        spring_3  percentile  17_group  \
# 231                       Символьные вычисления    0.000000     173.0
# 80   Дополнительные главы прикладной статистики    0.000000       0.0
# 91                          Машинное обучение 2    0.004484       0.0
# 273        Методы сжатия и передачи медиаданных    0.007246     175.0
# 19   Дополнительные главы прикладной статистики    0.008969       0.0
#
#                                    blended  is_ml_student
# 231  Введение в дифференциальную геометрию            0.0
# 80                                                    1.0
# 91                                                    0.0
# 273                                 DevOps            0.0
# 19                                                    0.0

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
quantity = 1 + (171 <= df['17_group']) * (df['17_group'] <= 173) + (df['18_group'] > 0) * (df['is_mi'] > 0)
quantity.head()
# Out:
# 231    2
# 80     1
# 91     1
# 273    1
# 19     1
# dtype: int32

# %%
quantity.value_counts()
# Out:
# 1    258
# 2     89
# dtype: int64

# %%
df['quantity'] = quantity
df.sample(5)
# Out:
#                      timestamp                                id  rating  \
# 240 2020-05-14 23:33:26.536999  276e2ccf4903d4ddf856b20a2b08394e    1123
# 26  2020-05-15 22:59:40.602001  a0c56e8aa03ea6c1f5e8462914472075     751
# 266 2020-05-17 19:44:23.500000  d028e00edda581b07bcbe6b841e6dc39    1242
# 44  2020-05-17 12:11:23.296000  39cd1820459fdbcc193f9bb0ddb74a58     606
# 89  2020-05-18 18:01:52.603999  fd784637a19d65bbe5b07d6efac5a05d     625
#
#      18_group  is_mi                                           fall_1  \
# 240       0.0    0.0            Байесовские методы машинного обучения
# 26      182.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 266       0.0    0.0            Байесовские методы машинного обучения
# 44      184.0    1.0                 Безопасность компьютерных систем
# 89      182.0    0.0                 Безопасность компьютерных систем
#
#                                               fall_2  \
# 240                      Statistical Learning Theory
# 26                       Statistical Learning Theory
# 266                Анализ неструктурированных данных
# 44   Сбор и обработка данных с помощью краудсорсинга
# 89                       Statistical Learning Theory
#
#                                    fall_3  \
# 240  Глубинное обучение в обработке звука
# 26          Моделирование временных рядов
# 266  Глубинное обучение в обработке звука
# 44            Statistical Learning Theory
# 89                   Матричные вычисления
#
#                                        spring_1  \
# 240                      Конфликты и кооперация
# 26   Дополнительные главы прикладной статистики
# 266                    Обучение с подкреплением
# 44                          Машинное обучение 2
# 89                          Машинное обучение 2
#
#                                         spring_2                 spring_3  \
# 240                     Обучение с подкреплением    Символьные вычисления
# 26                        Дискретная оптимизация         Численные методы
# 266      Генеративные модели в машинном обучении      Компьютерное зрение
# 44   Промышленное программирование на языке Java  Анализ данных в бизнесе
# 89                        Дискретная оптимизация        Компьютерные сети
#
#      percentile  17_group                                blended  \
# 240    0.623188     173.0  Введение в дифференциальную геометрию
# 26     0.044843       0.0
# 266    0.166667     171.0                                 DevOps
# 44     0.623318       0.0
# 89     0.533632       0.0
#
#      is_ml_student  quantity
# 240            0.0         2
# 26             1.0         1
# 266            0.0         2
# 44             0.0         2
# 89             0.0         1

# %% [markdown]
# Проверка:

# %%
col_name = 'quantity'

assert(df[df['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(df[df['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(df[df['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(df[df['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
df.drop(columns=['timestamp', 'rating', 'blended'], inplace=True)
df.rename(columns={'id':'ID'}, inplace=True)

# %%
fall_courses = set(np.unique(df[['fall_1', 'fall_2', 'fall_3']].values).tolist())
fall_groups = dict.fromkeys(fall_courses, 30)
fall_groups['Statistical Learning Theory'] = 60
fall_groups['Высокопроизводительные вычисления'] = 60
fall_groups['Анализ неструктурированных данных'] = 1000000
fall_groups
# Out:
# {'Глубинное обучение в обработке звука': 30,
#  'Теория баз данных': 30,
#  'Моделирование временных рядов': 30,
#  'Анализ неструктурированных данных': 1000000,
#  'Байесовские методы машинного обучения': 30,
#  'Матричные вычисления': 30,
#  'Язык SQL': 30,
#  'Сбор и обработка данных с помощью краудсорсинга': 30,
#  'Принятие решений в условиях риска и неопределённости': 30,
#  'Statistical Learning Theory': 60,
#  'Безопасность компьютерных систем': 30,
#  'Высокопроизводительные вычисления': 60}

# %%
df['course1'] = pd.Series(['-' for _ in range(df.index.size)], index=df.index)
df['course2'] = pd.Series(['-' for _ in range(df.index.size)], index=df.index)
df.head(5)
# Out:
#                                    ID  18_group  is_mi  \
# 231  3a7326c9e355a67d3805824ca34c4bc5       0.0    0.0
# 80   3e106aaef8b24dbb01319c73e14c2936     182.0    0.0
# 91   e0ca1a9548af9a3f98428c62420aa484     182.0    0.0
# 273  7fe7df0d207babbf30249b3063ac1f26       0.0    0.0
# 19   86d929f6fd741e56e93cee5900298849     181.0    0.0
#
#                                               fall_1  \
# 231                      Statistical Learning Theory
# 80                  Безопасность компьютерных систем
# 91                              Матричные вычисления
# 273                Высокопроизводительные вычисления
# 19   Сбор и обработка данных с помощью краудсорсинга
#
#                                               fall_2  \
# 231                Высокопроизводительные вычисления
# 80                       Statistical Learning Theory
# 91                  Безопасность компьютерных систем
# 273  Сбор и обработка данных с помощью краудсорсинга
# 19   Сбор и обработка данных с помощью краудсорсинга
#
#                                               fall_3  \
# 231                      Statistical Learning Theory
# 80                              Матричные вычисления
# 91                       Statistical Learning Theory
# 273                    Моделирование временных рядов
# 19   Сбор и обработка данных с помощью краудсорсинга
#
#                                               spring_1  \
# 231                              Символьные вычисления
# 80                              Дискретная оптимизация
# 91                              Дискретная оптимизация
# 273  Проектирование и разработка высоконагруженных ...
# 19          Дополнительные главы прикладной статистики
#
#                                         spring_2  \
# 231                             Численные методы
# 80   Промышленное программирование на языке Java
# 91    Дополнительные главы прикладной статистики
# 273         Методы сжатия и передачи медиаданных
# 19    Дополнительные главы прикладной статистики
#
#                                        spring_3  percentile  17_group  \
# 231                       Символьные вычисления    0.000000     173.0
# 80   Дополнительные главы прикладной статистики    0.000000       0.0
# 91                          Машинное обучение 2    0.004484       0.0
# 273        Методы сжатия и передачи медиаданных    0.007246     175.0
# 19   Дополнительные главы прикладной статистики    0.008969       0.0
#
#      is_ml_student  quantity course1 course2
# 231            0.0         2       -       -
# 80             1.0         1       -       -
# 91             0.0         1       -       -
# 273            0.0         1       -       -
# 19             0.0         1       -       -

# %%
'''
    Берем таблицу студентов с курсом в 1 приоритете, срезанную по числу свободных мест на курсе
    Студенты в ней отсортированы по %
    Эту таблицу делим на две: студенты, у которых 1 курс уже выбран и остальные
    От этих таблиц берем индексы и заполняем столбцы с курсами
'''

for course in fall_groups:
    new_df = df[ ( (df['fall_1'] == course) & (df['quantity'] == 1) |
                 ( (df['fall_1'] == course) | (df['fall_2'] == course) ) & 
                 (df['quantity'] == 2) )].iloc[:fall_groups[course]]
    
    ind_1 = new_df[new_df['course1'] == '-'].index   
    ind_2 = new_df[new_df['course1'] != '-'].index
    #print(len(ind_1), len(ind_2) )
    fall_groups[course] -= len(ind_1) + len(ind_2) 
    
    df.loc[ind_1, 'course1'] = course
    df.loc[ind_2, 'course2'] = course

# %%
df[ (df['course1'] == '-') & (df['course2'] != '-')].head(5)
# Out:
# Empty DataFrame
# Columns: [ID, 18_group, is_mi, fall_1, fall_2, fall_3, spring_1, spring_2, spring_3, percentile, 17_group, is_ml_student, quantity, course1, course2]
# Index: []

# %%
fall_groups
# Out:
# {'Глубинное обучение в обработке звука': 7,
#  'Теория баз данных': 16,
#  'Моделирование временных рядов': 0,
#  'Анализ неструктурированных данных': 999952,
#  'Байесовские методы машинного обучения': 6,
#  'Матричные вычисления': 15,
#  'Язык SQL': 1,
#  'Сбор и обработка данных с помощью краудсорсинга': 0,
#  'Принятие решений в условиях риска и неопределённости': 22,
#  'Statistical Learning Theory': 27,
#  'Безопасность компьютерных систем': 0,
#  'Высокопроизводительные вычисления': 16}

# %%
df[ (df['quantity'] == 1) & (df['course1'] == '-') ]['ID'].count()
# Out:
# 78

# %%
df[ (df['quantity'] == 2) & ((df['course1'] != '-') & (df['course2'] == '-')) ]['ID'].count()
# Out:
# 24

# %%
df[ (df['quantity'] == 2) & (df['course1'] == '-') & (df['course2'] == '-') ]['ID'].count()
# Out:
# 3

# %%
df[ (df['quantity'] == 2) & (df['course1'] != '-') & (df['course2'] != '-') ]['ID'].count()
# Out:
# 62

# %%
df[ (df['quantity'] == 1) & (df['course1'] != '-') & (df['course2'] == '-')]['ID'].count()
# Out:
# 180

# %% [markdown]
# #### 3. [3 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
for fall in ['fall_2', 'fall_3']:
    for course in fall_groups:
        # Простите за такое
        new_df = df[ (df['quantity'] == 1) & (df['course1'] == '-') & (df[fall] == course) |
                     (df['quantity'] == 2) & (df['course2'] == '-') & (df['fall_3'] == course) &
                   (df['course1'] != course) ].iloc[:fall_groups[course]]
        
        ind_l  = new_df[ (new_df['quantity'] == 1) & (new_df['course1'] == '-') & (new_df[fall] == course) ].index
        fall_groups[course] -= len(ind_l)
        df.loc[ind_l, 'course1'] = course
        
        # А тут может быть выбрано два курса
        if fall != 'fall_3':
            # Можно заполнить только второй курс
            ind_ll = new_df[ (new_df['quantity'] == 2) & (new_df['course2'] == '-') & (new_df['fall_3'] == course) ].index
            fall_groups[course] -= len(ind_ll)
            df.loc[ind_ll, 'course2'] = course

# %%
# Теперь надо заполнить '-'
ind_1 = df[ (df['quantity'] == 1) & (df['course1'] == '-') ].index
ind_2 = df[ (df['quantity'] == 2) & (df['course1'] == '-') & (df['course2'] == '-') ].index
ind_3 = df[ (df['quantity'] == 2) & (df['course1'] != '-') & (df['course2'] == '-') ].index
ind_4 = df[ (df['quantity'] == 2) & (df['course1'] == '-') & (df['course2'] != '-') ].index
df.loc[ind_1, 'course1'] = '???'
df.loc[ind_2, ['course1', 'course2']] = '???'
df.loc[ind_3, 'course2'] = '???'
df.loc[ind_4, 'course1'] = '???'

# %%
fall_groups
# Out:
# {'Глубинное обучение в обработке звука': 0,
#  'Теория баз данных': 6,
#  'Моделирование временных рядов': 0,
#  'Анализ неструктурированных данных': 999944,
#  'Байесовские методы машинного обучения': 5,
#  'Матричные вычисления': 0,
#  'Язык SQL': 0,
#  'Сбор и обработка данных с помощью краудсорсинга': 0,
#  'Принятие решений в условиях риска и неопределённости': 20,
#  'Statistical Learning Theory': 17,
#  'Безопасность компьютерных систем': 0,
#  'Высокопроизводительные вычисления': 0}

# %% [markdown]
# Посмотрим, сколько студентов, которые:
#     * Должны были выбрать 1 курс, но никуда не попали
#     * Должны были выбрать 2 курса, но попали лишь на один
#     * Должны были выбрать 2 курса, но ни на какой не попали

# %%
df[ (df['quantity'] == 1) & (df['course1'] == '???') ]['ID'].count()
# Out:
# 24

# %%
df[ (df['quantity'] == 2) & ((df['course1'] != '???') & (df['course2'] == '???')) ]['ID'].count()
# Out:
# 9

# %%
df[ (df['quantity'] == 2) & (df['course1'] == '???') & (df['course2'] == '???') ]['ID'].count()
# Out:
# 2

# %% [markdown]
# Успешно попали на свои курсы:

# %%
df[ (df['quantity'] == 2) & (df['course1'] != '???') & (df['course2'] != '???') ]['ID'].count()
# Out:
# 77

# %%
df[ (df['quantity'] == 1) & (df['course1'] != '???')]['ID'].count()
# Out:
# 234

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (https://contest.yandex.ru/contest/29176/problems/A/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %%
df[['ID', 'course1', 'course2']].to_csv('res_fall.csv', index=None)

# %% [markdown]
# *Дисклеймер:*
#
# Контест выдаётся для самопроверки. Если ваша посылка получила ОК, то код, скорее всего, правильный. Но при этом оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# **Дополнительное задание. [2 бонусных балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.**
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
#df.drop(columns=['fall_1', 'fall_2', 'fall_3', 'course1', 'course2'], inplace=True)
df['course3'] = pd.Series(['-' for _ in range(df.index.size)], index=df.index)
df['course4'] = pd.Series(['-' for _ in range(df.index.size)], index=df.index)

# %%
# Здесь всего четверо студентов, которые выбрали МО2, будучи на МО
# Поэтому, надеюсь, ничего страшного, если я не сделаю оптимально
ML2 = 'Машинное обучение 2'
new_df = df[(df['is_ml_student'] == 1) &
   ( (df['spring_1'] == ML2) |
     (df['spring_2'] == ML2) |
     (df['spring_3'] == ML2) )].copy()

print(new_df['ID'].count())

def place_change(first, second, third):
    if first == ML2:
        return second, third, ML2
    if second == ML2:
        return first, third, ML2
    
    return first, second, third
    
new_df[['spring_1', 'spring_2', 'spring_3']] = new_df.apply(lambda x:
                                                            pd.Series(place_change(x.spring_1, x.spring_2, x.spring_3), 
                                                            index=['spring_1', 'spring_2', 'spring_3']), axis=1)
check_ind = new_df.index
new_df.head()
# Out:
# 5
#                                    ID  18_group  is_mi  \
# 20   f0f6f3881894172a0f04e79b554b49e6     181.0    0.0
# 179  abceddfa2fc4eae8cff4a4e712abb3fb     183.0    0.0
# 119  fc2c60b8004aa91bc272df84628621ff     183.0    0.0
# 27   5daee1bd98559bb2c52373e416942225     182.0    0.0
# 137  6ed89e424179b0510e3f7c0cb7369ad6     187.0    0.0
#
#                                               fall_1  \
# 20                  Безопасность компьютерных систем
# 179                    Моделирование временных рядов
# 119                                         Язык SQL
# 27   Сбор и обработка данных с помощью краудсорсинга
# 137                    Моделирование временных рядов
#
#                                                 fall_2  \
# 20     Сбор и обработка данных с помощью краудсорсинга
# 179  Принятие решений в условиях риска и неопределё...
# 119    Сбор и обработка данных с помощью краудсорсинга
# 27                         Statistical Learning Theory
# 137                               Матричные вычисления
#
#                                                 fall_3  \
# 20   Принятие решений в условиях риска и неопределё...
# 179                        Statistical Learning Theory
# 119                        Statistical Learning Theory
# 27                       Моделирование временных рядов
# 137                                           Язык SQL
#
#                                         spring_1  \
# 20                              Численные методы
# 179  Промышленное программирование на языке Java
# 119                           Системы баз данных
# 27   Промышленное программирование на языке Java
# 137                      Анализ данных в бизнесе
#
#                                         spring_2             spring_3  \
# 20    Дополнительные главы прикладной статистики  Машинное обучение 2
# 179   Дополнительные главы прикладной статистики  Машинное обучение 2
# 119                      Анализ данных в бизнесе  Машинное обучение 2
# 27                       Анализ данных в бизнесе  Машинное обучение 2
# 137  Промышленное программирование на языке Java  Машинное обучение 2
#
#      percentile  17_group  is_ml_student  quantity  \
# 20     0.300448       0.0            1.0         1
# 179    0.345291       0.0            1.0         1
# 119    0.461883       0.0            1.0         1
# 27     0.681614       0.0            1.0         1
# 137    0.838565       0.0            1.0         1
#
#                                                course1 course2 course3 course4
# 20   Принятие решений в условиях риска и неопределё...       -       -       -
# 179                      Моделирование временных рядов       -       -       -
# 119                                           Язык SQL       -       -       -
# 27                         Statistical Learning Theory       -       -       -
# 137                      Моделирование временных рядов       -       -       -

# %%
# Так же нету тех, кто выбрал МО2 и выбирал 2 курса
df[(df['quantity'] == 2) & ( (df['spring_1'] == ML2) | (df['spring_2'] == ML2) | (df['spring_3'] == ML2) ) ].head()
# Out:
#                                    ID  18_group  is_mi  \
# 152  9015b809a29fb65ce23d7addf16d770d     188.0    1.0
# 81   701078e1e897399f675e96bdda5fb149     188.0    1.0
# 215  c154bbf18efdd4d760e52155eaa87929     185.0    1.0
# 35   2662600c2c37e11e62f6ee0b88452f22     182.0    1.0
# 44   39cd1820459fdbcc193f9bb0ddb74a58     184.0    1.0
#
#                                               fall_1  \
# 152                                         Язык SQL
# 81   Сбор и обработка данных с помощью краудсорсинга
# 215                 Безопасность компьютерных систем
# 35                       Statistical Learning Theory
# 44                  Безопасность компьютерных систем
#
#                                                 fall_2  \
# 152                      Моделирование временных рядов
# 81   Принятие решений в условиях риска и неопределё...
# 215    Сбор и обработка данных с помощью краудсорсинга
# 35     Сбор и обработка данных с помощью краудсорсинга
# 44     Сбор и обработка данных с помощью краудсорсинга
#
#                                                 fall_3  \
# 152                               Матричные вычисления
# 81                                   Теория баз данных
# 215                  Высокопроизводительные вычисления
# 35   Принятие решений в условиях риска и неопределё...
# 44                         Statistical Learning Theory
#
#                                         spring_1  \
# 152                          Машинное обучение 2
# 81   Промышленное программирование на языке Java
# 215                            Компьютерные сети
# 35                           Машинное обучение 2
# 44                           Машинное обучение 2
#
#                                         spring_2  \
# 152  Промышленное программирование на языке Java
# 81                           Машинное обучение 2
# 215                          Машинное обучение 2
# 35   Промышленное программирование на языке Java
# 44   Промышленное программирование на языке Java
#
#                                         spring_3  percentile  17_group  \
# 152                            Компьютерные сети    0.338565       0.0
# 81                       Анализ данных в бизнесе    0.475336       0.0
# 215  Промышленное программирование на языке Java    0.479821       0.0
# 35    Дополнительные главы прикладной статистики    0.520179       0.0
# 44                       Анализ данных в бизнесе    0.623318       0.0
#
#      is_ml_student  quantity                                          course1  \
# 152            0.0         2                    Моделирование временных рядов
# 81             0.0         2  Сбор и обработка данных с помощью краудсорсинга
# 215            0.0         2  Сбор и обработка данных с помощью краудсорсинга
# 35             0.0         2  Сбор и обработка данных с помощью краудсорсинга
# 44             0.0         2  Сбор и обработка данных с помощью краудсорсинга
#
#                                                course2 course3 course4
# 152                                           Язык SQL       -       -
# 81   Принятие решений в условиях риска и неопределё...       -       -
# 215                  Высокопроизводительные вычисления       -       -
# 35                         Statistical Learning Theory       -       -
# 44                         Statistical Learning Theory       -       -

# %%
df.sort_values('percentile', inplace=True)
df['quantity'] = 1 + (171 <= df['17_group']) * (df['17_group'] <= 173)
spring_courses = set(np.unique(df[['spring_1', 'spring_2', 'spring_3']].values).tolist())
spring_groups = dict.fromkeys(spring_courses, 30)
spring_groups['Обучение с подкреплением'] = 60
spring_groups['Анализ данных в бизнесе'] = 60
spring_groups
# Out:
# {'Компьютерное зрение': 30,
#  'Обучение с подкреплением': 60,
#  'Конфликты и кооперация': 30,
#  'Компьютерные сети': 30,
#  'Проектирование и разработка высоконагруженных сервисов': 30,
#  'Символьные вычисления': 30,
#  'Численные методы': 30,
#  'Дискретная оптимизация': 30,
#  'Промышленное программирование на языке Java': 30,
#  'Методы сжатия и передачи медиаданных': 30,
#  'Генеративные модели в машинном обучении': 30,
#  'Дополнительные главы прикладной статистики': 30,
#  'Системы баз данных': 30,
#  'Анализ данных в бизнесе': 60,
#  'Машинное обучение 2': 30}

# %%
df.loc[new_df.index] = new_df

# %%
for course in spring_groups:
    spring_df = df[
                    ( (df['spring_1'] == course) & (df['quantity'] == 1) |
                    ( (df['spring_1'] == course) | (df['spring_2'] == course) ) & (df['quantity'] == 2) )
                  ].iloc[:spring_groups[course]]
       
    ind_1 = spring_df[spring_df['course3'] == '-'].index   
    ind_2 = spring_df[spring_df['course3'] != '-'].index
    spring_groups[course] -= len(ind_1) + len(ind_2) 
    
    df.loc[ind_1, 'course3'] = course
    df.loc[ind_2, 'course4'] = course

# %%
df[(df['is_ml_student'] == 1) & (df['spring_3'] == ML2) ].head()
# Out:
#                                    ID  18_group  is_mi  \
# 20   f0f6f3881894172a0f04e79b554b49e6     181.0    0.0
# 179  abceddfa2fc4eae8cff4a4e712abb3fb     183.0    0.0
# 119  fc2c60b8004aa91bc272df84628621ff     183.0    0.0
# 27   5daee1bd98559bb2c52373e416942225     182.0    0.0
# 137  6ed89e424179b0510e3f7c0cb7369ad6     187.0    0.0
#
#                                               fall_1  \
# 20                  Безопасность компьютерных систем
# 179                    Моделирование временных рядов
# 119                                         Язык SQL
# 27   Сбор и обработка данных с помощью краудсорсинга
# 137                    Моделирование временных рядов
#
#                                                 fall_2  \
# 20     Сбор и обработка данных с помощью краудсорсинга
# 179  Принятие решений в условиях риска и неопределё...
# 119    Сбор и обработка данных с помощью краудсорсинга
# 27                         Statistical Learning Theory
# 137                               Матричные вычисления
#
#                                                 fall_3  \
# 20   Принятие решений в условиях риска и неопределё...
# 179                        Statistical Learning Theory
# 119                        Statistical Learning Theory
# 27                       Моделирование временных рядов
# 137                                           Язык SQL
#
#                                         spring_1  \
# 20                              Численные методы
# 179  Промышленное программирование на языке Java
# 119                           Системы баз данных
# 27   Промышленное программирование на языке Java
# 137                      Анализ данных в бизнесе
#
#                                         spring_2             spring_3  \
# 20    Дополнительные главы прикладной статистики  Машинное обучение 2
# 179   Дополнительные главы прикладной статистики  Машинное обучение 2
# 119                      Анализ данных в бизнесе  Машинное обучение 2
# 27                       Анализ данных в бизнесе  Машинное обучение 2
# 137  Промышленное программирование на языке Java  Машинное обучение 2
#
#      percentile  17_group  is_ml_student  quantity  \
# 20     0.300448       0.0            1.0         1
# 179    0.345291       0.0            1.0         1
# 119    0.461883       0.0            1.0         1
# 27     0.681614       0.0            1.0         1
# 137    0.838565       0.0            1.0         1
#
#                                                course1 course2  \
# 20   Принятие решений в условиях риска и неопределё...       -
# 179                      Моделирование временных рядов       -
# 119                                           Язык SQL       -
# 27                         Statistical Learning Theory       -
# 137                      Моделирование временных рядов       -
#
#                                          course3 course4
# 20                              Численные методы       -
# 179  Промышленное программирование на языке Java       -
# 119                           Системы баз данных       -
# 27                                             -       -
# 137                      Анализ данных в бизнесе       -

# %% [markdown]
# На этом моменте места на МО2 закончились, далее можно быть спокойным.

# %%
for spring in ['spring_2', 'spring_3']:
    for course in spring_groups:
            
        spring_df = df[ (df['quantity'] == 1) & (df['course3'] == '-') & (df[spring] == course) |
                      # & ( (df[spring] != ML2) | (df.is_ml_student != 1) ) |
                        (df['quantity'] == 2) & (df['course4'] == '-') & (df['spring_3'] == course) &
                        (df['course3'] != course)
                      ].iloc[:spring_groups[course]]
        
        ind_l  = spring_df[
                            (spring_df['quantity'] == 1) &
                            (spring_df['course3'] == '-') &
                            (spring_df[spring] == course)
                          ].index
        spring_groups[course] -= len(ind_l)
        df.loc[ind_l, 'course3'] = course
        
        # Это вторая волна для тех, кто должен был выбрать два курса
        if spring != 'spring_3':
            ind_ll = spring_df[
                                (spring_df['quantity'] == 2) &
                                (spring_df['course4'] == '-') &
                                (spring_df['spring_3'] == course)
                              ].index
            spring_groups[course] -= len(ind_ll)
            df.loc[ind_ll, 'course4'] = course

# %%
ind_1 = df[ (df['quantity'] == 1) & (df['course3'] == '-') ].index
ind_2 = df[ (df['quantity'] == 2) & (df['course3'] == '-') & (df['course4'] == '-') ].index
ind_3 = df[ (df['quantity'] == 2) & (df['course3'] != '-') & (df['course4'] == '-') ].index
ind_4 = df[ (df['quantity'] == 2) & (df['course3'] == '-') & (df['course4'] != '-') ].index
df.loc[ind_1, 'course3'] = '???'
df.loc[ind_2, ['course3', 'course4']] = '???'
df.loc[ind_3, 'course4'] = '???'
df.loc[ind_4, 'course3'] = '???'

# %%
df[ (df['course3'] == '???') & (df['course4'] == '-')]['ID'].count()
# Out:
# 19

# %%
df[ ((df['course3'] != '???') & (df['course4'] == '???')) ]['ID'].count()
# Out:
# 5

# %%
df[ (df['course3'] == '???') & (df['course4'] == '???') ]['ID'].count()
# Out:
# 0

# %%
df[ (df['course3'] != '???') & ( (df['course4'] != '???') & (df['course4'] != '-'))]['ID'].count()
# Out:
# 68

# %%
df[ (df['course3'] != '???')  & (df['course4'] == '-')]['ID'].count()
# Out:
# 255

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (https://contest.yandex.ru/contest/29176/problems/B/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %%
df[['ID', 'course3', 'course4']].rename(columns={'course3':'course1', 'course4':'course2'}).to_csv('res_spring.csv', index=None)
